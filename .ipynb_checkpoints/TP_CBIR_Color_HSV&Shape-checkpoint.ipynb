# %% [markdown]
# # TP-CBIR (Content Based Image Retrieval)
# # -----------------------------------------------------------------
#
# ## Réalisé par:
# ##                    - KANA NGUIMFACK Kévin
# ##                    - OUEDRAOGO Wend-Panga Jérémie

# %% [markdown]
# #### Il est question dans ce travail, d'implementer un système de recherche d'images par le contenu (CBIR), compte tenu des limites de systèmes de recherche par mots clés, très fastidieux pour une base énorme car annotation à la main, donc perte de temps, et performance influencée par les erreurs humaines. Alors nous utilisons cette approche automatisé (CBIR), permettant la recherche d'images, dans une base préalablement indexé,  à partir des descripteurs d'une image requête préalablement calculées, en utilisant une métrique de similarités. Nous exploitons ici, dans les sources multimédia images, les informations de couleur dans l'espace TSL ou HSV et de forme. Le dataset utilisé, est COIL-100, de 100 classes, avec un total de 7200 images.

# %% [markdown]
# # Baseline
# # ------------------------------
#
# ### 1- Chargement de tous les fichiers de notre dataset (100 classes, 72 images / classe)
# ### 2- Définition de fonctions des signatures (caractéristiques)
# #####    - Descripteurs de couleur: Histogramme de couleur (RGB)
# #####    - Descripteurs de forme: Calcul des	moments	et	des	caractéristiques
# ### 3- Indexation de la base de données COIL-100
# #####    - Sauvegarde des descripteurs sous format binaire pickle(.pkl)
# ### 4- Definition des métrique d'évaluation de similarité
# #####    - métrique d'évaluation de l'histogramme de couleurs: la	méthode	du	Chi-2	(ou	Chi-square)
# #####    - métrique d'évaluation de l'histogramme de couleurs: la	méthode	distance euclidienne
# #####    - métrique globale: la	somme pondéré des métriques ci-dessous
# ######   Distance	=	ω1	∗	dist_couleur	+	ω2	∗	dist_forme		,  Avec	ω1+ω2	=1.(par	défaut	ω1=	ω2	=	0,5)
# ### 5- Recherche d'images à partir d'une image requête
# #####   -Nous retournerons les 10 premiers resultas, selon un ordre croissante de similarité (la similarité est d'autant forte que la métrique est plus petite)
# ### 6- Evaluation sur 100 images requêtes ( 1 image / classes)

# %% [markdown]
# # Importation des libraries, pour notre travail

# %%
import cv2
import numpy as np
import pandas as pd
import glob
from math import copysign, log10
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

# %% [markdown]
# # Chargement dataset COIL-100
#
# ### Récupération de chaque fichier image, en utilisant la librairies glob

# %%
db_path='./coil-100/'

images_filenames  =  glob.glob( db_path +'*.png')
images_filenames
# Out:
# ['./coil-100/obj20__105.png',
#  './coil-100/obj90__325.png',
#  './coil-100/obj93__85.png',
#  './coil-100/obj55__195.png',
#  './coil-100/obj11__280.png',
#  './coil-100/obj81__340.png',
#  './coil-100/obj30__330.png',
#  './coil-100/obj86__80.png',
#  './coil-100/obj83__60.png',
#  './coil-100/obj89__20.png',
#  './coil-100/obj72__320.png',
#  './coil-100/obj31__10.png',
#  './coil-100/obj85__70.png',
#  './coil-100/obj94__220.png',
#  './coil-100/obj25__280.png',
#  './coil-100/obj16__60.png',
#  './coil-100/obj56__40.png',
#  './coil-100/obj3__160.png',
#  './coil-100/obj36__130.png',
#  './coil-100/obj79__125.png',
#  './coil-100/obj77__275.png',
#  './coil-100/obj56__235.png',
#  './coil-100/obj56__245.png',
#  './coil-100/obj72__215.png',
#  './coil-100/obj91__50.png',
#  './coil-100/obj72__0.png',
#  './coil-100/obj93__120.png',
#  './coil-100/obj86__135.png',
#  './coil-100/obj9__320.png',
#  './coil-100/obj36__280.png',
#  './coil-100/obj50__265.png',
#  './coil-100/obj79__115.png',
#  './coil-100/obj95__190.png',
#  './coil-100/obj58__135.png',
#  './coil-100/obj22__135.png',
#  './coil-100/obj29__115.png',
#  './coil-100/obj94__355.png',
#  './coil-100/obj80__325.png',
#  './coil-100/obj2__250.png',
#  './coil-100/obj99__260.png',
#  './coil-100/obj3__285.png',
#  './coil-100/obj86__325.png',
#  './coil-100/obj98__105.png',
#  './coil-100/obj91__355.png',
#  './coil-100/obj29__125.png',
#  './coil-100/obj94__335.png',
#  './coil-100/obj69__300.png',
#  './coil-100/obj87__220.png',
#  './coil-100/obj46__120.png',
#  './coil-100/obj41__20.png',
#  './coil-100/obj67__60.png',
#  './coil-100/obj66__5.png',
#  './coil-100/obj30__345.png',
#  './coil-100/obj39__135.png',
#  './coil-100/obj12__295.png',
#  './coil-100/obj17__215.png',
#  './coil-100/obj24__270.png',
#  './coil-100/obj68__160.png',
#  './coil-100/obj56__310.png',
#  './coil-100/obj57__50.png',
#  './coil-100/obj25__230.png',
#  './coil-100/obj72__210.png',
#  './coil-100/obj16__150.png',
#  './coil-100/obj61__290.png',
#  './coil-100/obj19__130.png',
#  './coil-100/obj20__310.png',
#  './coil-100/obj28__35.png',
#  './coil-100/obj15__105.png',
#  './coil-100/obj35__230.png',
#  './coil-100/obj57__335.png',
#  './coil-100/obj38__115.png',
#  './coil-100/obj99__105.png',
#  './coil-100/obj82__240.png',
#  './coil-100/obj95__205.png',
#  './coil-100/obj70__190.png',
#  './coil-100/obj30__145.png',
#  './coil-100/obj31__210.png',
#  './coil-100/obj42__85.png',
#  './coil-100/obj35__185.png',
#  './coil-100/obj88__290.png',
#  './coil-100/obj88__50.png',
#  './coil-100/obj4__50.png',
#  './coil-100/obj92__215.png',
#  './coil-100/obj46__85.png',
#  './coil-100/obj87__335.png',
#  './coil-100/obj16__50.png',
#  './coil-100/obj59__35.png',
#  './coil-100/obj4__290.png',
#  './coil-100/obj2__145.png',
#  './coil-100/obj16__170.png',
#  './coil-100/obj29__145.png',
#  './coil-100/obj54__335.png',
#  './coil-100/obj8__345.png',
#  './coil-100/obj61__130.png',
#  './coil-100/obj24__135.png',
#  './coil-100/obj10__275.png',
#  './coil-100/obj87__185.png',
#  './coil-100/obj98__130.png',
#  './coil-100/obj75__350.png',
#  './coil-100/obj78__250.png',
#  './coil-100/obj74__105.png',
#  './coil-100/obj43__40.png',
#  './coil-100/obj35__275.png',
#  './coil-100/obj90__260.png',
#  './coil-100/obj83__45.png',
#  './coil-100/obj79__80.png',
#  './coil-100/obj16__220.png',
#  './coil-100/obj42__65.png',
#  './coil-100/obj72__285.png',
#  './coil-100/obj66__0.png',
#  './coil-100/obj51__280.png',
#  './coil-100/obj49__85.png',
#  './coil-100/obj86__100.png',
#  './coil-100/obj68__355.png',
#  './coil-100/obj37__200.png',
#  './coil-100/obj97__235.png',
#  './coil-100/obj6__20.png',
#  './coil-100/obj98__355.png',
#  './coil-100/obj13__155.png',
#  './coil-100/obj28__280.png',
#  './coil-100/obj65__45.png',
#  './coil-100/obj62__305.png',
#  './coil-100/obj7__5.png',
#  './coil-100/obj39__300.png',
#  './coil-100/obj44__315.png',
#  './coil-100/obj42__295.png',
#  './coil-100/obj70__135.png',
#  './coil-100/obj51__315.png',
#  './coil-100/obj71__255.png',
#  './coil-100/obj49__255.png',
#  './coil-100/obj40__35.png',
#  './coil-100/obj69__260.png',
#  './coil-100/obj93__45.png',
#  './coil-100/obj62__0.png',
#  './coil-100/obj78__170.png',
#  './coil-100/obj59__30.png',
#  './coil-100/obj51__55.png',
#  './coil-100/obj95__15.png',
#  './coil-100/obj76__50.png',
#  './coil-100/obj20__180.png',
#  './coil-100/obj57__100.png',
#  './coil-100/obj37__40.png',
#  './coil-100/obj84__55.png',
#  './coil-100/obj75__130.png',
#  './coil-100/obj27__250.png',
#  './coil-100/obj42__5.png',
#  './coil-100/obj16__290.png',
#  './coil-100/obj98__90.png',
#  './coil-100/obj69__245.png',
#  './coil-100/obj9__140.png',
#  './coil-100/obj52__325.png',
#  './coil-100/obj73__75.png',
#  './coil-100/obj82__35.png',
#  './coil-100/obj100__345.png',
#  './coil-100/obj97__330.png',
#  './coil-100/obj99__0.png',
#  './coil-100/obj27__205.png',
#  './coil-100/obj81__240.png',
#  './coil-100/obj98__235.png',
#  './coil-100/obj83__120.png',
#  './coil-100/obj4__285.png',
#  './coil-100/obj100__240.png',
#  './coil-100/obj58__85.png',
#  './coil-100/obj71__20.png',
#  './coil-100/obj48__285.png',
#  './coil-100/obj68__320.png',
#  './coil-100/obj90__265.png',
#  './coil-100/obj25__355.png',
#  './coil-100/obj51__230.png',
#  './coil-100/obj93__60.png',
#  './coil-100/obj84__60.png',
#  './coil-100/obj65__220.png',
#  './coil-100/obj45__225.png',
#  './coil-100/obj27__200.png',
#  './coil-100/obj40__85.png',
#  './coil-100/obj83__115.png',
#  './coil-100/obj38__260.png',
#  './coil-100/obj85__155.png',
#  './coil-100/obj63__250.png',
#  './coil-100/obj67__85.png',
#  './coil-100/obj84__215.png',
#  './coil-100/obj51__145.png',
#  './coil-100/obj98__240.png',
#  './coil-100/obj68__0.png',
#  './coil-100/obj16__355.png',
#  './coil-100/obj41__140.png',
#  './coil-100/obj30__205.png',
#  './coil-100/obj85__165.png',
#  './coil-100/obj23__110.png',
#  './coil-100/obj100__190.png',
#  './coil-100/obj58__40.png',
#  './coil-100/obj71__55.png',
#  './coil-100/obj4__160.png',
#  './coil-100/obj82__125.png',
#  './coil-100/obj11__230.png',
#  './coil-100/obj92__330.png',
#  './coil-100/obj78__220.png',
#  './coil-100/obj43__355.png',
#  './coil-100/obj30__200.png',
#  './coil-100/obj78__225.png',
#  './coil-100/obj62__265.png',
#  './coil-100/obj62__235.png',
#  './coil-100/obj98__135.png',
#  './coil-100/obj34__145.png',
#  './coil-100/obj41__10.png',
#  './coil-100/obj26__315.png',
#  './coil-100/obj40__205.png',
#  './coil-100/obj42__125.png',
#  './coil-100/obj82__5.png',
#  './coil-100/obj16__285.png',
#  './coil-100/obj23__205.png',
#  './coil-100/obj46__335.png',
#  './coil-100/obj54__325.png',
#  './coil-100/obj86__260.png',
#  './coil-100/obj61__210.png',
#  './coil-100/obj90__90.png',
#  './coil-100/obj71__145.png',
#  './coil-100/obj59__80.png',
#  './coil-100/obj99__335.png',
#  './coil-100/obj19__30.png',
#  './coil-100/obj55__60.png',
#  './coil-100/obj12__110.png',
#  './coil-100/obj44__30.png',
#  './coil-100/obj94__315.png',
#  './coil-100/obj35__290.png',
#  './coil-100/obj20__265.png',
#  './coil-100/obj64__310.png',
#  './coil-100/obj95__100.png',
#  './coil-100/obj80__165.png',
#  './coil-100/obj83__70.png',
#  './coil-100/obj84__25.png',
#  './coil-100/obj100__220.png',
#  './coil-100/obj26__25.png',
#  './coil-100/obj72__195.png',
#  './coil-100/obj76__205.png',
#  './coil-100/obj72__95.png',
#  './coil-100/obj4__35.png',
#  './coil-100/obj34__195.png',
#  './coil-100/obj40__250.png',
#  './coil-100/obj16__95.png',
#  './coil-100/obj59__265.png',
#  './coil-100/obj66__10.png',
#  './coil-100/obj70__0.png',
#  './coil-100/obj35__270.png',
#  './coil-100/obj91__195.png',
#  './coil-100/obj40__215.png',
#  './coil-100/obj61__65.png',
#  './coil-100/obj57__120.png',
#  './coil-100/obj74__130.png',
#  './coil-100/obj16__135.png',
#  './coil-100/obj76__255.png',
#  './coil-100/obj58__25.png',
#  './coil-100/obj31__355.png',
#  './coil-100/obj86__25.png',
#  './coil-100/obj89__250.png',
#  './coil-100/obj18__275.png',
#  './coil-100/obj47__300.png',
#  './coil-100/obj15__265.png',
#  './coil-100/obj62__100.png',
#  './coil-100/obj76__320.png',
#  './coil-100/obj15__200.png',
#  './coil-100/obj70__95.png',
#  './coil-100/obj76__300.png',
#  './coil-100/obj51__330.png',
#  './coil-100/obj89__320.png',
#  './coil-100/obj85__105.png',
#  './coil-100/obj65__325.png',
#  './coil-100/obj43__280.png',
#  './coil-100/obj56__295.png',
#  './coil-100/obj75__310.png',
#  './coil-100/obj71__320.png',
#  './coil-100/obj25__15.png',
#  './coil-100/obj42__20.png',
#  './coil-100/obj43__270.png',
#  './coil-100/obj97__40.png',
#  './coil-100/obj16__340.png',
#  './coil-100/obj53__255.png',
#  './coil-100/obj79__145.png',
#  './coil-100/obj64__100.png',
#  './coil-100/obj65__345.png',
#  './coil-100/obj17__110.png',
#  './coil-100/obj96__0.png',
#  './coil-100/obj43__130.png',
#  './coil-100/obj76__225.png',
#  './coil-100/obj20__345.png',
#  './coil-100/obj55__225.png',
#  './coil-100/obj70__195.png',
#  './coil-100/obj44__15.png',
#  './coil-100/obj100__215.png',
#  './coil-100/obj80__10.png',
#  './coil-100/obj40__65.png',
#  './coil-100/obj27__335.png',
#  './coil-100/obj13__295.png',
#  './coil-100/obj46__195.png',
#  './coil-100/obj54__135.png',
#  './coil-100/obj53__130.png',
#  './coil-100/obj36__20.png',
#  './coil-100/obj80__240.png',
#  './coil-100/obj36__40.png',
#  './coil-100/obj37__60.png',
#  './coil-100/obj74__40.png',
#  './coil-100/obj5__255.png',
#  './coil-100/obj89__180.png',
#  './coil-100/obj18__270.png',
#  './coil-100/obj84__140.png',
#  './coil-100/obj13__340.png',
#  './coil-100/obj67__350.png',
#  './coil-100/obj84__230.png',
#  './coil-100/obj63__65.png',
#  './coil-100/obj23__35.png',
#  './coil-100/obj96__90.png',
#  './coil-100/obj8__285.png',
#  './coil-100/obj29__350.png',
#  './coil-100/obj28__135.png',
#  './coil-100/obj82__330.png',
#  './coil-100/obj26__230.png',
#  './coil-100/obj37__280.png',
#  './coil-100/obj8__135.png',
#  './coil-100/obj74__160.png',
#  './coil-100/obj71__30.png',
#  './coil-100/obj30__115.png',
#  './coil-100/obj41__135.png',
#  './coil-100/obj71__125.png',
#  './coil-100/obj38__280.png',
#  './coil-100/obj41__50.png',
#  './coil-100/obj37__95.png',
#  './coil-100/obj1__165.png',
#  './coil-100/obj55__0.png',
#  './coil-100/obj63__220.png',
#  './coil-100/obj94__240.png',
#  './coil-100/obj5__355.png',
#  './coil-100/obj50__200.png',
#  './coil-100/obj85__10.png',
#  './coil-100/obj91__115.png',
#  './coil-100/obj15__35.png',
#  './coil-100/obj65__200.png',
#  './coil-100/obj25__180.png',
#  './coil-100/obj27__330.png',
#  './coil-100/obj80__30.png',
#  './coil-100/obj47__355.png',
#  './coil-100/obj3__25.png',
#  './coil-100/obj11__0.png',
#  './coil-100/obj60__320.png',
#  './coil-100/obj70__355.png',
#  './coil-100/obj23__105.png',
#  './coil-100/obj90__165.png',
#  './coil-100/obj40__5.png',
#  './coil-100/obj3__350.png',
#  './coil-100/obj19__305.png',
#  './coil-100/obj50__230.png',
#  './coil-100/obj85__260.png',
#  './coil-100/obj73__25.png',
#  './coil-100/obj73__210.png',
#  './coil-100/obj67__185.png',
#  './coil-100/obj69__30.png',
#  './coil-100/obj49__5.png',
#  './coil-100/obj16__255.png',
#  './coil-100/obj76__195.png',
#  './coil-100/obj95__25.png',
#  './coil-100/obj57__160.png',
#  './coil-100/obj83__320.png',
#  './coil-100/obj53__100.png',
#  './coil-100/obj71__270.png',
#  './coil-100/obj88__190.png',
#  './coil-100/obj51__65.png',
#  './coil-100/obj51__255.png',
#  './coil-100/obj91__285.png',
#  './coil-100/obj54__165.png',
#  './coil-100/obj81__20.png',
#  './coil-100/obj70__325.png',
#  './coil-100/obj80__345.png',
#  './coil-100/obj66__175.png',
#  './coil-100/obj56__225.png',
#  './coil-100/obj61__0.png',
#  './coil-100/obj56__240.png',
#  './coil-100/obj51__25.png',
#  './coil-100/obj32__255.png',
#  './coil-100/obj14__40.png',
#  './coil-100/obj14__0.png',
#  './coil-100/obj71__355.png',
#  './coil-100/obj70__290.png',
#  './coil-100/obj80__60.png',
#  './coil-100/obj88__150.png',
#  './coil-100/obj97__290.png',
#  './coil-100/obj46__95.png',
#  './coil-100/obj55__125.png',
#  './coil-100/obj19__25.png',
#  './coil-100/obj22__265.png',
#  './coil-100/obj34__340.png',
#  './coil-100/obj67__80.png',
#  './coil-100/obj29__175.png',
#  './coil-100/obj6__210.png',
#  './coil-100/obj35__330.png',
#  './coil-100/obj7__330.png',
#  './coil-100/obj80__260.png',
#  './coil-100/obj52__45.png',
#  './coil-100/obj29__265.png',
#  './coil-100/obj88__140.png',
#  './coil-100/obj85__50.png',
#  './coil-100/obj64__335.png',
#  './coil-100/obj67__140.png',
#  './coil-100/obj35__240.png',
#  './coil-100/obj20__260.png',
#  './coil-100/obj97__65.png',
#  './coil-100/obj100__225.png',
#  './coil-100/obj100__260.png',
#  './coil-100/obj58__185.png',
#  './coil-100/obj13__95.png',
#  './coil-100/obj45__205.png',
#  './coil-100/obj30__175.png',
#  './coil-100/obj83__100.png',
#  './coil-100/obj40__320.png',
#  './coil-100/obj44__90.png',
#  './coil-100/obj68__10.png',
#  './coil-100/obj91__125.png',
#  './coil-100/obj25__325.png',
#  './coil-100/obj92__265.png',
#  './coil-100/obj74__115.png',
#  './coil-100/obj11__105.png',
#  './coil-100/obj3__245.png',
#  './coil-100/obj78__265.png',
#  './coil-100/obj12__220.png',
#  './coil-100/obj61__140.png',
#  './coil-100/obj68__215.png',
#  './coil-100/obj11__330.png',
#  './coil-100/obj46__240.png',
#  './coil-100/obj75__330.png',
#  './coil-100/obj25__90.png',
#  './coil-100/obj81__125.png',
#  './coil-100/obj45__85.png',
#  './coil-100/obj32__285.png',
#  './coil-100/obj60__200.png',
#  './coil-100/obj68__150.png',
#  './coil-100/obj17__305.png',
#  './coil-100/obj4__85.png',
#  './coil-100/obj11__250.png',
#  './coil-100/obj52__180.png',
#  './coil-100/obj78__140.png',
#  './coil-100/obj56__325.png',
#  './coil-100/obj76__315.png',
#  './coil-100/obj77__115.png',
#  './coil-100/obj20__0.png',
#  './coil-100/obj64__120.png',
#  './coil-100/obj53__185.png',
#  './coil-100/obj22__25.png',
#  './coil-100/obj30__285.png',
#  './coil-100/obj100__110.png',
#  './coil-100/obj51__200.png',
#  './coil-100/obj10__290.png',
#  './coil-100/obj84__170.png',
#  './coil-100/obj18__350.png',
#  './coil-100/obj100__230.png',
#  './coil-100/obj44__0.png',
#  './coil-100/obj27__155.png',
#  './coil-100/obj43__325.png',
#  './coil-100/obj87__145.png',
#  './coil-100/obj9__220.png',
#  './coil-100/obj21__240.png',
#  './coil-100/obj40__20.png',
#  './coil-100/obj76__285.png',
#  './coil-100/obj86__210.png',
#  './coil-100/obj20__80.png',
#  './coil-100/obj63__305.png',
#  './coil-100/obj5__280.png',
#  './coil-100/obj29__245.png',
#  './coil-100/obj13__325.png',
#  './coil-100/obj9__25.png',
#  './coil-100/obj17__345.png',
#  './coil-100/obj79__165.png',
#  './coil-100/obj80__280.png',
#  './coil-100/obj72__355.png',
#  './coil-100/obj68__335.png',
#  './coil-100/obj72__105.png',
#  './coil-100/obj50__35.png',
#  './coil-100/obj40__275.png',
#  './coil-100/obj48__35.png',
#  './coil-100/obj36__235.png',
#  './coil-100/obj12__145.png',
#  './coil-100/obj90__280.png',
#  './coil-100/obj46__65.png',
#  './coil-100/obj43__75.png',
#  './coil-100/obj89__140.png',
#  './coil-100/obj80__0.png',
#  './coil-100/obj41__5.png',
#  './coil-100/obj83__305.png',
#  './coil-100/obj22__35.png',
#  './coil-100/obj78__55.png',
#  './coil-100/obj14__235.png',
#  './coil-100/obj63__105.png',
#  './coil-100/obj6__325.png',
#  './coil-100/obj23__285.png',
#  './coil-100/obj40__105.png',
#  './coil-100/obj30__185.png',
#  './coil-100/obj53__150.png',
#  './coil-100/obj98__260.png',
#  './coil-100/obj38__225.png',
#  './coil-100/obj82__275.png',
#  './coil-100/obj39__30.png',
#  './coil-100/obj45__355.png',
#  './coil-100/obj98__65.png',
#  './coil-100/obj51__155.png',
#  './coil-100/obj44__175.png',
#  './coil-100/obj59__165.png',
#  './coil-100/obj30__25.png',
#  './coil-100/obj70__165.png',
#  './coil-100/obj50__125.png',
#  './coil-100/obj59__105.png',
#  './coil-100/obj45__65.png',
#  './coil-100/obj44__340.png',
#  './coil-100/obj35__280.png',
#  './coil-100/obj95__55.png',
#  './coil-100/obj1__5.png',
#  './coil-100/obj34__310.png',
#  './coil-100/obj52__110.png',
#  './coil-100/obj8__280.png',
#  './coil-100/obj66__25.png',
#  './coil-100/obj33__225.png',
#  './coil-100/obj11__40.png',
#  './coil-100/obj82__185.png',
#  './coil-100/obj32__270.png',
#  './coil-100/obj57__170.png',
#  './coil-100/obj53__115.png',
#  './coil-100/obj26__345.png',
#  './coil-100/obj82__130.png',
#  './coil-100/obj16__250.png',
#  './coil-100/obj66__165.png',
#  './coil-100/obj69__220.png',
#  './coil-100/obj93__135.png',
#  './coil-100/obj87__330.png',
#  './coil-100/obj23__245.png',
#  './coil-100/obj28__190.png',
#  './coil-100/obj84__285.png',
#  './coil-100/obj38__315.png',
#  './coil-100/obj77__265.png',
#  './coil-100/obj97__275.png',
#  './coil-100/obj69__5.png',
#  './coil-100/obj73__180.png',
#  './coil-100/obj51__45.png',
#  './coil-100/obj27__105.png',
#  './coil-100/obj81__90.png',
#  './coil-100/obj34__40.png',
#  './coil-100/obj43__330.png',
#  './coil-100/obj28__150.png',
#  './coil-100/obj30__325.png',
#  './coil-100/obj61__185.png',
#  './coil-100/obj77__120.png',
#  './coil-100/obj31__255.png',
#  './coil-100/obj48__340.png',
#  './coil-100/obj61__55.png',
#  './coil-100/obj90__315.png',
#  './coil-100/obj73__135.png',
#  './coil-100/obj51__310.png',
#  './coil-100/obj100__280.png',
#  './coil-100/obj90__20.png',
#  './coil-100/obj49__135.png',
#  './coil-100/obj30__240.png',
#  './coil-100/obj43__140.png',
#  './coil-100/obj49__300.png',
#  './coil-100/obj41__225.png',
#  './coil-100/obj3__220.png',
#  './coil-100/obj54__185.png',
#  './coil-100/obj26__320.png',
#  './coil-100/obj57__225.png',
#  './coil-100/obj91__145.png',
#  './coil-100/obj60__220.png',
#  './coil-100/obj73__110.png',
#  './coil-100/obj80__290.png',
#  './coil-100/obj75__65.png',
#  './coil-100/obj76__150.png',
#  './coil-100/obj6__320.png',
#  './coil-100/obj35__45.png',
#  './coil-100/obj54__115.png',
#  './coil-100/obj63__175.png',
#  './coil-100/obj97__260.png',
#  './coil-100/obj1__25.png',
#  './coil-100/obj41__190.png',
#  './coil-100/obj20__140.png',
#  './coil-100/obj61__275.png',
#  './coil-100/obj58__10.png',
#  './coil-100/obj81__285.png',
#  './coil-100/obj64__135.png',
#  './coil-100/obj2__5.png',
#  './coil-100/obj27__195.png',
#  './coil-100/obj85__350.png',
#  './coil-100/obj17__320.png',
#  './coil-100/obj39__230.png',
#  './coil-100/obj30__220.png',
#  './coil-100/obj15__350.png',
#  './coil-100/obj44__240.png',
#  './coil-100/obj86__300.png',
#  './coil-100/obj77__110.png',
#  './coil-100/obj80__335.png',
#  './coil-100/obj44__120.png',
#  './coil-100/obj70__130.png',
#  './coil-100/obj61__45.png',
#  './coil-100/obj50__260.png',
#  './coil-100/obj5__95.png',
#  './coil-100/obj5__190.png',
#  './coil-100/obj66__260.png',
#  './coil-100/obj89__160.png',
#  './coil-100/obj19__160.png',
#  './coil-100/obj76__145.png',
#  './coil-100/obj72__220.png',
#  './coil-100/obj24__150.png',
#  './coil-100/obj10__90.png',
#  './coil-100/obj6__130.png',
#  './coil-100/obj93__130.png',
#  './coil-100/obj83__0.png',
#  './coil-100/obj97__220.png',
#  './coil-100/obj34__10.png',
#  './coil-100/obj55__270.png',
#  './coil-100/obj27__135.png',
#  './coil-100/obj42__220.png',
#  './coil-100/obj57__355.png',
#  './coil-100/obj7__140.png',
#  './coil-100/obj82__270.png',
#  './coil-100/obj82__230.png',
#  './coil-100/obj11__285.png',
#  './coil-100/obj26__350.png',
#  './coil-100/obj64__190.png',
#  './coil-100/obj70__40.png',
#  './coil-100/obj1__305.png',
#  './coil-100/obj41__25.png',
#  './coil-100/obj8__340.png',
#  './coil-100/obj71__290.png',
#  './coil-100/obj88__185.png',
#  './coil-100/obj86__255.png',
#  './coil-100/obj88__60.png',
#  './coil-100/obj33__65.png',
#  './coil-100/obj13__125.png',
#  './coil-100/obj68__325.png',
#  './coil-100/obj2__85.png',
#  './coil-100/obj69__275.png',
#  './coil-100/obj78__25.png',
#  './coil-100/obj77__85.png',
#  './coil-100/obj58__60.png',
#  './coil-100/obj36__15.png',
#  './coil-100/obj55__25.png',
#  './coil-100/obj69__295.png',
#  './coil-100/obj91__280.png',
#  './coil-100/obj28__285.png',
#  './coil-100/obj56__65.png',
#  './coil-100/obj2__270.png',
#  './coil-100/obj62__205.png',
#  './coil-100/obj55__140.png',
#  './coil-100/obj83__30.png',
#  './coil-100/obj92__255.png',
#  './coil-100/obj89__85.png',
#  './coil-100/obj63__300.png',
#  './coil-100/obj9__125.png',
#  './coil-100/obj82__285.png',
#  './coil-100/obj51__260.png',
#  './coil-100/obj23__5.png',
#  './coil-100/obj3__100.png',
#  './coil-100/obj80__120.png',
#  './coil-100/obj36__220.png',
#  './coil-100/obj22__340.png',
#  './coil-100/obj60__265.png',
#  './coil-100/obj73__265.png',
#  './coil-100/obj50__245.png',
#  './coil-100/obj65__270.png',
#  './coil-100/obj100__0.png',
#  './coil-100/obj83__110.png',
#  './coil-100/obj76__120.png',
#  './coil-100/obj97__90.png',
#  './coil-100/obj11__35.png',
#  './coil-100/obj82__295.png',
#  './coil-100/obj42__335.png',
#  './coil-100/obj9__15.png',
#  './coil-100/obj53__275.png',
#  './coil-100/obj36__135.png',
#  './coil-100/obj2__335.png',
#  './coil-100/obj84__80.png',
#  './coil-100/obj82__85.png',
#  './coil-100/obj59__290.png',
#  './coil-100/obj45__15.png',
#  './coil-100/obj98__35.png',
#  './coil-100/obj19__265.png',
#  './coil-100/obj6__60.png',
#  './coil-100/obj69__210.png',
#  './coil-100/obj11__170.png',
#  './coil-100/obj36__95.png',
#  './coil-100/obj24__80.png',
#  './coil-100/obj62__215.png',
#  './coil-100/obj30__225.png',
#  './coil-100/obj17__255.png',
#  './coil-100/obj6__215.png',
#  './coil-100/obj74__220.png',
#  './coil-100/obj11__215.png',
#  './coil-100/obj68__205.png',
#  './coil-100/obj99__65.png',
#  './coil-100/obj50__155.png',
#  './coil-100/obj23__130.png',
#  './coil-100/obj19__50.png',
#  './coil-100/obj86__345.png',
#  './coil-100/obj22__55.png',
#  './coil-100/obj75__220.png',
#  './coil-100/obj32__35.png',
#  './coil-100/obj61__200.png',
#  './coil-100/obj17__25.png',
#  './coil-100/obj87__355.png',
#  './coil-100/obj38__70.png',
#  './coil-100/obj24__110.png',
#  './coil-100/obj43__335.png',
#  './coil-100/obj71__200.png',
#  './coil-100/obj82__250.png',
#  './coil-100/obj79__235.png',
#  './coil-100/obj32__320.png',
#  './coil-100/obj85__45.png',
#  './coil-100/obj14__300.png',
#  './coil-100/obj61__260.png',
#  './coil-100/obj85__235.png',
#  './coil-100/obj47__100.png',
#  './coil-100/obj25__305.png',
#  './coil-100/obj32__5.png',
#  './coil-100/obj64__210.png',
#  './coil-100/obj23__25.png',
#  './coil-100/obj76__330.png',
#  './coil-100/obj13__230.png',
#  './coil-100/obj92__250.png',
#  './coil-100/obj51__70.png',
#  './coil-100/obj74__205.png',
#  './coil-100/obj17__55.png',
#  './coil-100/obj7__305.png',
#  './coil-100/obj10__65.png',
#  './coil-100/obj46__75.png',
#  './coil-100/obj44__270.png',
#  './coil-100/obj45__305.png',
#  './coil-100/obj89__60.png',
#  './coil-100/obj51__120.png',
#  './coil-100/obj78__290.png',
#  './coil-100/obj58__50.png',
#  './coil-100/obj94__65.png',
#  './coil-100/obj88__265.png',
#  './coil-100/obj57__25.png',
#  './coil-100/obj7__90.png',
#  './coil-100/obj64__225.png',
#  './coil-100/obj99__120.png',
#  './coil-100/obj64__305.png',
#  './coil-100/obj22__145.png',
#  './coil-100/obj95__320.png',
#  './coil-100/obj18__95.png',
#  './coil-100/obj18__305.png',
#  './coil-100/obj41__110.png',
#  './coil-100/obj16__325.png',
#  './coil-100/obj79__110.png',
#  './coil-100/obj94__30.png',
#  './coil-100/obj40__90.png',
#  './coil-100/obj28__85.png',
#  './coil-100/obj33__280.png',
#  './coil-100/obj65__110.png',
#  './coil-100/obj15__125.png',
#  './coil-100/obj98__0.png',
#  './coil-100/obj100__20.png',
#  './coil-100/obj98__85.png',
#  './coil-100/obj40__75.png',
#  './coil-100/obj41__120.png',
#  './coil-100/obj58__155.png',
#  './coil-100/obj28__330.png',
#  './coil-100/obj72__25.png',
#  './coil-100/obj19__235.png',
#  './coil-100/obj78__45.png',
#  './coil-100/obj19__295.png',
#  './coil-100/obj14__170.png',
#  './coil-100/obj39__165.png',
#  './coil-100/obj12__80.png',
#  './coil-100/obj49__200.png',
#  './coil-100/obj73__130.png',
#  './coil-100/obj33__40.png',
#  './coil-100/obj100__320.png',
#  './coil-100/obj42__120.png',
#  './coil-100/obj50__45.png',
#  './coil-100/obj57__280.png',
#  './coil-100/obj62__315.png',
#  './coil-100/obj52__195.png',
#  './coil-100/obj32__160.png',
#  './coil-100/obj7__170.png',
#  './coil-100/obj58__270.png',
#  './coil-100/obj19__145.png',
#  './coil-100/obj57__195.png',
#  './coil-100/obj15__180.png',
#  './coil-100/obj26__300.png',
#  './coil-100/obj77__20.png',
#  './coil-100/obj83__220.png',
#  './coil-100/obj34__355.png',
#  './coil-100/obj40__190.png',
#  './coil-100/obj44__325.png',
#  './coil-100/obj58__95.png',
#  './coil-100/obj40__55.png',
#  './coil-100/obj84__220.png',
#  './coil-100/obj82__15.png',
#  './coil-100/obj85__20.png',
#  './coil-100/obj14__195.png',
#  './coil-100/obj72__240.png',
#  './coil-100/obj85__60.png',
#  './coil-100/obj78__340.png',
#  './coil-100/obj29__80.png',
#  './coil-100/obj81__330.png',
#  './coil-100/obj41__205.png',
#  './coil-100/obj10__20.png',
#  './coil-100/obj41__245.png',
#  './coil-100/obj65__100.png',
#  './coil-100/obj5__5.png',
#  './coil-100/obj74__195.png',
#  './coil-100/obj74__335.png',
#  './coil-100/obj40__345.png',
#  './coil-100/obj91__340.png',
#  './coil-100/obj60__45.png',
#  './coil-100/obj66__270.png',
#  './coil-100/obj73__70.png',
#  './coil-100/obj100__130.png',
#  './coil-100/obj61__135.png',
#  './coil-100/obj52__235.png',
#  './coil-100/obj99__340.png',
#  './coil-100/obj61__245.png',
#  './coil-100/obj69__55.png',
#  './coil-100/obj98__165.png',
#  './coil-100/obj56__350.png',
#  './coil-100/obj34__80.png',
#  './coil-100/obj33__150.png',
#  './coil-100/obj44__130.png',
#  './coil-100/obj77__5.png',
#  './coil-100/obj78__50.png',
#  './coil-100/obj93__215.png',
#  './coil-100/obj7__30.png',
#  './coil-100/obj17__105.png',
#  './coil-100/obj51__220.png',
#  './coil-100/obj91__245.png',
#  './coil-100/obj34__115.png',
#  './coil-100/obj92__15.png',
#  './coil-100/obj82__320.png',
#  './coil-100/obj35__260.png',
#  './coil-100/obj50__170.png',
#  './coil-100/obj46__315.png',
#  './coil-100/obj99__225.png',
#  './coil-100/obj68__340.png',
#  './coil-100/obj73__310.png',
#  './coil-100/obj53__340.png',
#  './coil-100/obj67__100.png',
#  './coil-100/obj42__130.png',
#  './coil-100/obj76__105.png',
#  './coil-100/obj43__310.png',
#  './coil-100/obj36__250.png',
#  './coil-100/obj85__25.png',
#  './coil-100/obj33__185.png',
#  './coil-100/obj48__20.png',
#  './coil-100/obj49__90.png',
#  './coil-100/obj3__345.png',
#  './coil-100/obj21__235.png',
#  './coil-100/obj10__95.png',
#  './coil-100/obj24__20.png',
#  './coil-100/obj42__350.png',
#  './coil-100/obj81__65.png',
#  './coil-100/obj56__75.png',
#  './coil-100/obj42__200.png',
#  './coil-100/obj53__335.png',
#  './coil-100/obj36__25.png',
#  './coil-100/obj14__55.png',
#  './coil-100/obj39__225.png',
#  './coil-100/obj38__330.png',
#  './coil-100/obj55__320.png',
#  './coil-100/obj45__35.png',
#  './coil-100/obj89__240.png',
#  './coil-100/obj12__190.png',
#  './coil-100/obj18__120.png',
#  './coil-100/obj91__45.png',
#  './coil-100/obj33__260.png',
#  './coil-100/obj31__95.png',
#  './coil-100/obj22__160.png',
#  './coil-100/obj46__245.png',
#  './coil-100/obj66__20.png',
#  './coil-100/obj48__305.png',
#  './coil-100/obj23__355.png',
#  './coil-100/obj37__130.png',
#  './coil-100/obj60__95.png',
#  './coil-100/obj31__120.png',
#  './coil-100/obj49__15.png',
#  './coil-100/obj51__355.png',
#  './coil-100/obj19__255.png',
#  './coil-100/obj19__325.png',
#  './coil-100/obj87__190.png',
#  './coil-100/obj5__260.png',
#  './coil-100/obj30__355.png',
#  './coil-100/obj98__270.png',
#  './coil-100/obj16__300.png',
#  './coil-100/obj96__350.png',
#  './coil-100/obj55__245.png',
#  './coil-100/obj61__70.png',
#  './coil-100/obj39__95.png',
#  './coil-100/obj61__310.png',
#  './coil-100/obj79__85.png',
#  './coil-100/obj7__250.png',
#  './coil-100/obj2__290.png',
#  './coil-100/obj12__25.png',
#  './coil-100/obj13__165.png',
#  './coil-100/obj16__245.png',
#  './coil-100/obj60__330.png',
#  './coil-100/obj32__290.png',
#  './coil-100/obj19__240.png',
#  './coil-100/obj37__45.png',
#  './coil-100/obj53__135.png',
#  './coil-100/obj29__235.png',
#  './coil-100/obj60__175.png',
#  './coil-100/obj72__10.png',
#  './coil-100/obj51__170.png',
#  './coil-100/obj16__100.png',
#  './coil-100/obj67__150.png',
#  './coil-100/obj41__295.png',
#  './coil-100/obj4__125.png',
#  './coil-100/obj47__50.png',
#  './coil-100/obj43__5.png',
#  './coil-100/obj33__210.png',
#  './coil-100/obj52__355.png',
#  './coil-100/obj96__50.png',
#  './coil-100/obj100__15.png',
#  './coil-100/obj46__0.png',
#  './coil-100/obj13__220.png',
#  './coil-100/obj20__165.png',
#  './coil-100/obj4__215.png',
#  './coil-100/obj31__285.png',
#  './coil-100/obj16__235.png',
#  './coil-100/obj84__260.png',
#  './coil-100/obj74__120.png',
#  './coil-100/obj13__280.png',
#  './coil-100/obj5__265.png',
#  './coil-100/obj7__80.png',
#  './coil-100/obj11__140.png',
#  './coil-100/obj63__310.png',
#  './coil-100/obj61__195.png',
#  './coil-100/obj84__45.png',
#  './coil-100/obj78__175.png',
#  './coil-100/obj91__65.png',
#  './coil-100/obj89__15.png',
#  './coil-100/obj49__140.png',
#  './coil-100/obj36__125.png',
#  './coil-100/obj81__185.png',
#  './coil-100/obj38__170.png',
#  './coil-100/obj19__15.png',
#  './coil-100/obj85__170.png',
#  './coil-100/obj54__265.png',
#  './coil-100/obj56__335.png',
#  './coil-100/obj24__90.png',
#  './coil-100/obj18__205.png',
#  './coil-100/obj48__240.png',
#  './coil-100/obj94__345.png',
#  './coil-100/obj84__115.png',
#  './coil-100/obj39__335.png',
#  './coil-100/obj18__320.png',
#  './coil-100/obj20__125.png',
#  './coil-100/obj31__50.png',
#  './coil-100/obj60__285.png',
#  './coil-100/obj26__165.png',
#  './coil-100/obj88__210.png',
#  './coil-100/obj69__240.png',
#  './coil-100/obj74__100.png',
#  './coil-100/obj1__20.png',
#  './coil-100/obj71__140.png',
#  './coil-100/obj96__40.png',
#  './coil-100/obj97__185.png',
#  './coil-100/obj27__65.png',
#  './coil-100/obj83__90.png',
#  './coil-100/obj43__160.png',
#  './coil-100/obj25__300.png',
#  './coil-100/obj17__135.png',
#  './coil-100/obj5__230.png',
#  './coil-100/obj91__90.png',
#  './coil-100/obj6__330.png',
#  './coil-100/obj8__20.png',
#  './coil-100/obj59__145.png',
#  './coil-100/obj6__110.png',
#  './coil-100/obj21__220.png',
#  './coil-100/obj77__290.png',
#  './coil-100/obj36__330.png',
#  './coil-100/obj14__5.png',
#  './coil-100/obj88__260.png',
#  './coil-100/obj41__340.png',
#  './coil-100/obj28__210.png',
#  './coil-100/obj2__100.png',
#  './coil-100/obj37__190.png',
#  './coil-100/obj6__185.png',
#  './coil-100/obj20__175.png',
#  './coil-100/obj39__325.png',
#  './coil-100/obj73__270.png',
#  './coil-100/obj46__160.png',
#  './coil-100/obj28__250.png',
#  './coil-100/obj8__25.png',
#  './coil-100/obj10__295.png',
#  './coil-100/obj45__295.png',
#  './coil-100/obj49__230.png',
#  './coil-100/obj73__290.png',
#  './coil-100/obj23__140.png',
#  './coil-100/obj66__325.png',
#  './coil-100/obj94__75.png',
#  './coil-100/obj75__165.png',
#  './coil-100/obj73__195.png',
#  './coil-100/obj99__305.png',
#  './coil-100/obj85__95.png',
#  './coil-100/obj88__120.png',
#  './coil-100/obj17__120.png',
#  './coil-100/obj14__260.png',
#  ...]

# %%
print("COIL-100, nombre d'images: {}".format(len(images_filenames)))
# Out:
# COIL-100, nombre d'images: 7200

# %% [markdown]
# # Définition de fonctions des signatures (caractéristiques)

# %% [markdown]
# ### __Step__ 0: Reduction de la quantification
# ##### Les valeurs de l'images étant comprises entre 0  et 255, il s'agit de leur ramené entre 0 et 32. A cet effet nous avons eu à choisir 32 valeurs.
#
# #### La fonction reduceQuantification, prend en paramètres, une images couleur de quantification 0-255 et la nouvelle valeur maximale de quantification prédéfinie (quantification_value, ici fixé à 32), et retourne une image couleur de quantification 0-32

# %%
# reduction of number value
quantification_value = 32

def reduceQuantification(nb_values = quantification_value , image = None):
    # Diviser l'image en ses differents channel, rouge, vert, et blue.
    R, G, B= cv2.split(image)
    
    for i in range(B.shape[0]): # B.shape[0]: hauteur de l'image
        for j in range(B.shape[1]): # B.shape[1]: largeur de l'image
            B[i][j] = round(B[i][j] * nb_values / 255)
            G[i][j] = round(G[i][j] * nb_values / 255)
            R[i][j] = round(R[i][j] * nb_values / 255)
    
    # Fusionner les differentes channel pour obtenir l'image couleur initiale
    image = cv2.merge((R, G, B))        
    return image

# %% [markdown]
# ### __Step__ 1: Fonction d'extraction d' extraction des caractéristiques de couleurs (histogramme couleur)
# #### Pour une image donnée, nous construisons ici deux types d'histogramme,un histogramme de taille 3*32 (96) et un autre  histogramme 3D de dimensions 32x32x32 (32768) par intersection de couleurs, pour cela la fonction calHist de la librairie opencv est utilisée, puis nous normalisons les histogrammes et aplatissons l'histogramme dans le cas  3D ainsi  afin d'avoir le vecteur caractéristique couleur de l'image de taille 32768 .
#
# #### Les fonction Histo3DFeatureColor et Histo3DFeatureColor, prennent en paramètres, une image couleur et les bacs d'histogramme prédéfinis, et retourne un vecteur de caractéristique d' histogramme couleur.
#
# #### Mais compte de la taille élévée du vecteur de caractéristique obtenu de l'histogramme 3D, nous utilisons ici l'histogramme de taille de taille 96, étant la concaténation des histogrammes 1D de taille 32 sur chaque channels, afin de gagner en temps de calcul.

# %%
_bins = (32,32,32)

def Histo3DFeatureColor(image = None, bins= _bins):
    hist = cv2.calcHist([image], [0, 1, 2], None, bins,[0, 32, 0, 32, 0, 32])
    # Normalisation de l'histogramme, pour reduire l'influence du nombre de pixels pour chaque bins.
    features_vector = cv2.normalize(hist, hist).flatten()
    return np.asarray(features_vector)

def HistoFeatureColor(image = None, bins= 32):
    
    hist_b = cv2.calcHist([image], [2], None, [bins],[0, 32])
    hist_g = cv2.calcHist([image], [1], None, [bins],[0, 32])
    hist_r = cv2.calcHist([image], [0], None, [bins],[0, 32])
    # Normalisation de l'histogramme, pour reduire l'influence du nombre de pixels pour chaque bins.
    hist_b = cv2.normalize(hist_b,hist_b)
    hist_g = cv2.normalize(hist_g,hist_g)
    hist_r = cv2.normalize(hist_r,hist_r)
    
    # concatenation
    histoCat = np.concatenate((hist_b,hist_g), axis=None)
    histoCat = np.concatenate((histoCat, hist_r), axis=None)
    
    return np.asarray(histoCat)

# %% [markdown]
# ### __Step__ 2: Fonction d'extraction des caractéristiques de forme (Moments de Hu)
# #### L'image couleur cible sera préalablement convertir en niveau de gris. Puis calculer les moments et les caractéristiques de l'image donnée, le moment de Hu permet d'estimer la forme de l'object dans une 'image. Les caractéristiques de Hu définis, au nombre de 7, seront déduits des moments précalculés.
#
# #### Etapes:
# ##### - convertion image en niveau de gray.
# ##### - Utiliser une approche de segmentation par seuillage  (resultat image noir-blanc, image binaire).
# ##### - Calcul des moments associés à l'image ( la moyenne pondérée des intensités de pixels de l'image).
# ##### - Déterminer les caractéristiques du Moment de Hu (au nombre de 7), de l'object.
# #### Les invariants de moment Hu sont calculés en utilisant des moments centraux invariants aux transformations d'image. Les 6 premiers moments se sont avérés être invariants à la translation, à l'échelle, à la rotation et à la réflexion. Et le signe du 7ème moment change pour la réflexion de l'image.
#
# #### La fonction ObjectFeatureShape, prend en paramètre une image couleur, et retourne les caractéristiques de Hu associés à l'image.

# %%
def ObjectFeatureShape(image = None):
    # convertir l'image en niveau de gris
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    # seuillage adaptative de l'image
    _, gray_th_otsu = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    # calcul des moments centraux de l'images
    moments = cv2.moments(gray_th_otsu)
    # calcul des moments de Hu (7) en utilisants les moments centraux
    Hu_moments = cv2.HuMoments(moments)
    """
        Notons que les moments de Hu, ainsi obtenus, sont parfois très variables à l'echelle.
        Afin de palier à ce problème, nous les ramenons sur la même echelle, en effectuant 
        une transformation logarithmique decimale, tel que H(i) = -sign(hi)log10(|hi|)
    """
    for i in range(0,7):
        Hu_moments[i] = -1 * copysign(1.0, Hu_moments[i]) * log10(abs(Hu_moments[i]))
        
    return np.asarray(Hu_moments.flatten())

# %% [markdown]
# # Indexation de la base de données COIL-100

# %% [markdown]
# # -----------------------------------------------------------------
# ### Calcul des différentes signatures, sur notre dataset COIL-100
#
# #### La fonction DatasetIndexing, prend en paramètres, l'ensemble des fichiers de notre dataset.
# #### Pour chaque fichier image, nous procédons comme suite:
# ##### - Lecture du fichier image
# ##### - Extraction des caractéristiques de couleurs et de forme
# ##### - Mise à jour de la structure de données, data prédéfinir
# #### En fin sauvegarde du fichier data au format binaire pickle(.pkl).

# %%
def DatasetIndexing(images_files = images_filenames):
    """
        Definition de notre structure de données pour la sauvegarde des signatures 
        (histogramme de couleurs + descripteurs de Hu) et des noms d'images associés
    """
    data = pd.DataFrame(columns=("name_file","features_color", "features_shape"))
    for filename in images_files:
        # lire le fichier image
        _img = cv2.imread(filename)
        _img = cv2.cvtColor(_img, cv2.COLOR_BGR2RGB)
        img = reduceQuantification(nb_values = quantification_value , image = _img)
        # extraction des caractéristiques de couleurs de l'image
        features_color = HistoFeatureColor(image = img, bins = 32)
        # extraction des caractéristiques de forme de l'image
        features_shape = ObjectFeatureShape(image = img)
        # pour contenir les informations courantes, avant insertion dans data
        dic = dict()
        fn = filename.split('/') # séparation du chemin relatif par le séparateur '/'

        dic["name_file"] = fn[2] #extraction du nom de l'image 
        dic["features_color"] = features_color
        dic["features_shape"] = features_shape
            
        # mise à jour de variable de stockage data 
        data = data.append(dic, ignore_index=True)
        
    # Sauvegarde du dataset après indexation
    data.to_pickle("IndexingDataset.pkl")

# %%
DatasetIndexing(images_files = images_filenames)

# %% [markdown]
# ### Prévisualisation de la sauvegarde

# %%
indexed_db = pd.read_pickle('IndexingDataset.pkl')

# %%
# affichage des 10 premiers lignes
indexed_db.head(10)
# Out:
#         name_file                                     features_color  \
# 0  obj20__105.png  [0.0031384968, 0.020086378, 0.09490814, 0.9402...
# 1  obj90__325.png  [0.0021612635, 0.006577758, 0.054877296, 0.986...
# 2   obj93__85.png  [0.00038604913, 0.0039570034, 0.19842926, 0.97...
# 3  obj55__195.png  [0.0, 0.010646585, 0.048022896, 0.74186313, 0....
# 4  obj11__280.png  [0.0, 0.0018382324, 0.16053896, 0.9341897, 0.1...
# 5  obj81__340.png  [0.0, 0.008925141, 0.29628763, 0.8914322, 0.21...
# 6  obj30__330.png  [0.00022796108, 0.004673202, 0.121617235, 0.97...
# 7   obj86__80.png  [0.0003896021, 0.0055842963, 0.07960869, 0.943...
# 8   obj83__60.png  [0.024732675, 0.2647493, 0.4021801, 0.843835, ...
# 9   obj89__20.png  [0.0, 0.00015653898, 0.015027743, 0.8928984, 0...
#
#                                       features_shape
# 0  [3.001966129607334, 6.579216781115412, 10.2606...
# 1  [2.804446450463385, 5.865106807089411, 9.22343...
# 2  [2.9941863659821424, 6.323365186405546, 9.7935...
# 3  [3.15523197868933, 7.743223982295529, 10.77530...
# 4  [3.144574987206589, 7.00370220491629, 10.67299...
# 5  [2.694029322086657, 8.746101882102247, 8.51452...
# 6  [3.0454146567097222, 6.769891867439611, 10.007...
# 7  [3.087784648081366, 6.8561580029635305, 10.805...
# 8  [3.174572184563596, 7.620239643099023, 10.4049...
# 9  [3.009894249703678, 6.648599800363823, 9.85820...

# %%
# afficher nom première image
indexed_db["name_file"][0]
# Out:
# 'obj20__105.png'

# %%
# afficher features_color première image
indexed_db["features_color"][0]
# Out:
# array([3.13849677e-03, 2.00863779e-02, 9.49081406e-02, 9.40293610e-01,
#        1.93959102e-01, 1.33825496e-01, 9.89254192e-02, 8.91333073e-02,
#        1.04323633e-01, 7.70814791e-02, 6.05102144e-02, 7.48217627e-02,
#        6.74149096e-02, 4.08004560e-02, 2.46058144e-02, 1.46881649e-02,
#        5.02159446e-03, 2.88741686e-03, 2.13417783e-03, 1.88309804e-03,
#        1.75755820e-03, 1.25539862e-03, 1.88309804e-03, 1.12985878e-03,
#        3.76619602e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 9.54878796e-03, 9.52001095e-01,
#        1.14716262e-01, 3.97648178e-02, 6.01704456e-02, 1.00066066e-01,
#        1.17201567e-01, 8.84243920e-02, 6.68415204e-02, 6.72339350e-02,
#        6.97192326e-02, 8.88168141e-02, 7.76983574e-02, 7.10272864e-02,
#        7.73059428e-02, 5.28453477e-02, 3.38785760e-02, 2.72075068e-02,
#        1.19032841e-02, 5.88623947e-03, 1.96207967e-03, 2.22369051e-03,
#        1.96207967e-03, 1.30805315e-03, 2.22369051e-03, 1.04644254e-03,
#        1.30805318e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.68334043e-03, 9.54376996e-01,
#        1.16351739e-01, 4.69797589e-02, 3.84912044e-02, 2.63437908e-02,
#        2.15140954e-02, 2.01969054e-02, 2.45875381e-02, 2.54656635e-02,
#        3.62958871e-02, 5.60537316e-02, 7.37626106e-02, 9.35204551e-02,
#        7.66896978e-02, 6.95183352e-02, 6.10297807e-02, 6.62985370e-02,
#        6.04443625e-02, 6.90792724e-02, 7.53725097e-02, 5.63464388e-02,
#        5.15167452e-02, 4.99068461e-02, 5.60537316e-02, 5.48828952e-02,
#        3.77594307e-02, 3.24906744e-02, 2.15140954e-02, 9.65938997e-03],
#       dtype=float32)

# %%
# afficher nom features_shape première image
indexed_db["features_shape"][0]
# Out:
# array([  3.00196613,   6.57921678,  10.26060017,  10.48310894,
#         20.90758846,  13.77333282, -21.18852605])

# %%
# taille caractéristique couleurs
indexed_db["features_color"][0].shape
# Out:
# (96,)

# %%
# taille caractéristiques forme
indexed_db["features_shape"][0].shape
# Out:
# (7,)

# %% [markdown]
# # Definition des métrique d'évaluation de similarité

# %% [markdown]
# ### __Step__ 1: Métrique d'évaluation de l'histogramme de couleurs: la méthode du Chi-2 (ou Chi-square)
# #### Nous utilisons ici la fonction Chi-2, qui tire son nom de la statistique de test du chi carré de Pearson, utilisée pour comparer les distributions de probabilité discrètes.
#
# #### Notre fonction, chi2Distance prend en paramètres, une descripteur couleur de notre base indexée, et le descripteur couleur de l'image requête, et un dernier paramètre eps permettant d'éviter les division par zéro.
# #### Elle retourne la distance descrivant la similarité entre les deux histogrammes, plus elle est grande et moins ils sont similaires.

# %%
def Chi2Distance(features_color_db = None, features_color_query = None, eps = 1e-10):
    # calcul de la distance chi-squared
    dist_chi2 = 0.5 * np.sum([((a - b) ** 2) / (a + b + eps) 
                              for (a, b) in zip(features_color_db, features_color_query)])
    
    return dist_chi2

# %% [markdown]
# ### __Step__ 2: Métrique d'évaluation de forme (Moments de Hu): la méthode distance euclidienne
#
# #### Nous calculons la distance euclidienne entre  deux descripteurs de Hu, respectivement  un descripteur de reférence dans notre base indexée et le descripteur de l'image requête.
# #### La fonction, DistanceEuclidienne prend ses 2 paramètres, et retourne la distance descrivant la similarité entre les deux moments de Hu, plus elle est grande et moins ils sont similaires.

# %%
def DistanceEuclidienne(features_shape_db = None, features_shape_query = None):
    # calcul de la distance euclidiene
    dist = np.sum([((a - b) ** 2) for (a, b) in zip(features_shape_db, features_shape_query)])
    dist = np.sqrt(dist)
    
    return dist

# %% [markdown]
# ### __Step__ 3: Métrique globale: la somme pondéré des métriques ci-dessous
# #### Distance = ω1 ∗ dist_couleur + ω2 ∗ dist_forme , Avec ω1+ω2 =1.(par défaut ω1= ω2 = 0,5)
# #### La fonction Distance, prend en paramètres les métriques de signature de couleur et de forme, de l'image requête par rapport aux signatures couleur et forme d'une image donnée de la base modèle. Et elle retorne la distance pondérée calculée.

# %%
# Initialisation des poids
w1 = 0.45
w2 = 0.65

def Distance(dist_color = None, dist_shape = None):
    # Calcul de la métrique pondérée, à par des métriques de signature de couleur et de forme
    if dist_color > dist_shape:
        w1 = 0.20
        w2 = 0.80
    elif dist_color < dist_shape:
        w1 = 0.80
        w2 = 0.20
    else:
        w1 = 0.50
        w2 = 0.50
    distance = w1 * dist_color + w2 * dist_shape
    
    return distance

# %% [markdown]
# # Recherche d'images similaires, à partir d'une image requête
# ### Definition de la fonction de recherche.
# #### La fonction RechercheImagesFromImageReq, prend en paramètres l'image requête et l' ensemble d'images de notre base indexée, et retourne les 10 meilleurs resultats, dans l'ordre de similarités la plus forte (selon les distance croissante).

# %%
# nombre maximum de resultats les plus proches à afficher
NB_RESULTATS = 10
def RechercheImagesFromImageReq(path_image_query = None, indexed_db = indexed_db):
    # lire image requête
    img_query = cv2.imread(path_image_query)
    # convertir dans l' espace RGB
    img_query = cv2.cvtColor(img_query, cv2.COLOR_BGR2RGB)
    # reduction de la quantification
    img_query = reduceQuantification(nb_values = quantification_value , image = img_query)
    # Extraction caractéristique couleur et forme, de l'image requête
    query_features_color = HistoFeatureColor(image=img_query, bins=32)
    query_features_shape = ObjectFeatureShape(image=img_query)
    # draw histogramme image query
    displayHisto(img_origine = img_query, Histo = query_features_color)
    # supprimer l'image requête de la mémoire
    del img_query
    """
     list_resultats contenient,la distance de similarité de chaque image reférence 
     par rapport à l'image requête 
    """
    list_resultats = list()
    # mesure de similarités
    for ft_color_db, ft_shape_db in zip(indexed_db["features_color"].values.tolist(), 
                                              indexed_db["features_shape"].values.tolist()):
        # calcul métrique couleur
        dist_color = Chi2Distance(features_color_db=ft_color_db, features_color_query=query_features_color)
        # calcul métrique forme
        dist_shape = DistanceEuclidienne(features_shape_db=ft_shape_db, features_shape_query=query_features_shape)
        # calcul métrique pondérée
        distance = Distance(dist_color=dist_color, dist_shape=dist_shape)
        # mise à jour des resultats
        list_resultats.append(distance)
        
    """
    trier les resultats dans l'ordre croissant, par rapport aux indices 
    (la plus petite distance à son indice en première position et la plus grande en dernière position)
    """
    results_ord_indices = np.argsort(list_resultats)
    # garder les 10 premiers resultats (les meilleurs)
    results_ord_indices = results_ord_indices[:10]
    # recupérer la liste de noms d'images indexées
    noms_images_db = np.asarray(indexed_db["name_file"])
    # recupérer les noms images resultats
    noms_images_resultats = noms_images_db[results_ord_indices]
    # convertir liste distance en array
    list_resultats = np.array(list_resultats)
    # recupérer les distances images resultats
    distances_resultats = list_resultats[results_ord_indices]
    
    # retourner les resultats noms et distance de la requête
    return noms_images_resultats, distances_resultats


"""
    Fonction d'affichage histogramme de l'image requête
""" 
def displayHisto(img_origine = None, Histo = None):
  plt.subplot(221), plt.imshow(img_origine)
  plt.subplot(222), plt.plot(Histo[:32], color='b'), plt.plot(Histo[32:64], color='g'),plt.plot(Histo[64:96], color='r')
  plt.xlim([0,32])

  plt.show()



"""
    Fonction d'affichage resultats
""" 
def afficheResultats(image_query = None, resultats_noms = None, resultats_dist = None):
    print("> recherche  --input  {}".format(image_query),"\n")
    print("Images                     Distances")
    print("------                     ---------")
    for nom, dist in zip(resultats_noms, resultats_dist) :
         print("{}\t\t {}\n".format(nom, dist))

# %% [markdown]
# ### Recherche à partir d'une image requête

# %%
# nous utilisons prémière une image
path_image_query = "./coil-100/obj100__95.png"

resultats_noms, resultats_dist = RechercheImagesFromImageReq(path_image_query=path_image_query, indexed_db=indexed_db)

# %%
afficheResultats(image_query = path_image_query, resultats_noms = resultats_noms, resultats_dist = resultats_dist)
# Out:
# > recherche  --input  ./coil-100/obj100__95.png
#
# Images                     Distances
# ------                     ---------
# obj100__95.png		 0.0
#
# obj2__105.png		 1.1163420706284444
#
# obj2__110.png		 1.6482213141904691
#
# obj4__100.png		 2.06485146986375
#
# obj2__115.png		 2.1118421978255815
#
# obj4__95.png		 2.138961788564636
#
# obj15__90.png		 2.342766631879895
#
# obj85__135.png		 2.4006045344552893
#
# obj38__90.png		 2.474680417008925
#
# obj63__65.png		 2.547351130658004

# %% [markdown]
# # Evaluation sur 100 images requêtes ( 1 image / classes)
# ### La fonction evaluate, retourne une matrice de confusion de taille 100 x 100, chaque ligne correspond à l'image de test utilisé, et les colonnes vont contenir le nombre d'occurence pour chaque image resultat parmi 10.

# %%
test_path = './test/'
def evaluate(test = test_path, indexed_db = indexed_db):
    cf = np.zeros((100,100))
    images_filenames_test  =  glob.glob( test_path +'*.png')
    # faire la recherche pour chaque image de test et mettre à jour la matrice de confusion
    for fname_test in images_filenames_test:
        # recupérer l'id de l'image test
        id_test = getId(fname_test)
        # recherche d'images similaires
        resultats_noms, _ = RechercheImagesFromImageReq(path_image_query = fname_test, indexed_db = indexed_db)
        # Mise à jour de la matrice de confusion
        cf = UpdateConfMatrix(cf = cf, id_test = id_test, resultats = resultats_noms)
    
    # returner la matrice de confusion
    return cf

"""
   Fonction pour recuperer l'id de l'image à partir de son nom
"""
def getId(name_file = None):
    n_file = name_file.split('__')
    n_id = n_file[0].split('j')
    id = int(n_id[1])
    return id

"""
   Fonction pour mettre à jour la matrice confusion 100X100, de 0-99
"""
def UpdateConfMatrix(cf=None, id_test = None, resultats = None ):
    for res in resultats:
        # recuperer l'id du nom de fichier resultat
        id_res = getId(res)
        # incrementer la case correspondant de 1 pour le resultat prédire, à partir de id_test
        cf[id_test-1][id_res-1] = cf[id_test-1][id_res-1] + 1
    
    return cf

# %%
cf = evaluate(test = test_path, indexed_db = indexed_db)

# %%
# afficher matrice de confusion des 100 images requêtes
print(cf)
# Out:
# [[ 9.  0.  0. ...  0.  0.  0.]
#  [ 0. 10.  0. ...  0.  0.  0.]
#  [ 0.  0. 10. ...  0.  0.  0.]
#  ...
#  [ 4.  0.  0. ...  5.  0.  0.]
#  [ 0.  0.  0. ...  0.  8.  0.]
#  [ 0.  0.  0. ...  0.  0. 10.]]

# %% [markdown]
# ### Dessiner la matrice des 100 requêtes (1 image / classe)
# #### Nous constatons dans notre matrice de confusion, que chaque classe image requête nous avons au moins en moyenne 5 résultats images bonnes.
# #### Fonction pour dessiner, la matrix de confusion

# %%
cf_matrix = cf
plt.figure(figsize=(8, 8))
plt.imshow(cf_matrix, interpolation='nearest', cmap='Blues')
plt.title('confusion matrix')
plt.colorbar()
plt.show()

# %% [markdown]
# ### Performance obtenue sur l'evaluation de 100 images requêtes (1 image/ classe)

# %%
accuracy = np.trace(cf) / float(np.sum(cf))
print("Accuracy d'évaluation:  {}%\nErreur d'évaluation: {}%".format(accuracy * 100, (1-accuracy) * 100))
# Out:
# Accuracy d'évaluation:  74.6%
# Erreur d'évaluation: 25.4%

# %% [markdown]
# ### CONCLUSION EXPERIMENTATION: Il s'agissait ici pour nous d'améliorer au mieux que possible la métrique globale pondérée des métrique de coleurs et de forme, en ajustant les valeurs des poids w1 pour la métrique couleur et w2 celle de forme.
# ### - Initialement nous avons opté pour une proportion équitable de poids, w1=w2=0,50 . Les résultats obtenus n'étaient pas satisfaisantes soit:
# ### - Alors après plusieurs essais pour différentes valeurs de poids, nous avons opté pour une distribution w1 = 0,80 et w2=0,20, qui s'est avéré fournir de bons résultats sur notre jeux d'évaluation de 100 image(1 image/classes). Nous Obtenons ainsi une performance de 77,3%, avec une marge d'erreur de 22,7%. Mais cette distribution arrêtée, ne généralisait pas sur nos nouvelles images requêtes constituées (téléchargées sur internet), soit au plus 1 seul bon resultat parmi 10. Alors nous avons opté pour une nouvelle distribution des poids.
# ### - Nous nous fissons pour objectif de miminiser au maximun la distance pondérée(maximiser la similarité), en acceptant perdre 2,7% de la performance précédente (77,3%), pour une marge d'erreurs totale de 25.4%, afin d'améliorer le mieux possible la généralisation des resultats sur une image requête donnée. Pour cela nous assignons des poids équitables (0,50) si les distances couleur et forme sont égales.  w1=0,80  et w2 = 0,20 si la distance forme est supérieur à la distance couleur, sinon w1 = 0,20 et w2=0,80. Cela nous a permi d'obtenir de meilleurs résultats, par rapport au précendant qui renvoyait pratiquement aucun bon résultats.
# # ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Test sur une image requête quelconque
# ### Fonction pour afficher les images résultats

# %%
def AfficherResultats(resultats = None):
    nb_columns = 5
    nb_line = 2
    fig, ax = plt.subplots(nb_line, nb_columns, sharex=True, sharey=True, figsize=(10,10))
    k = 0
    for i in range(nb_line):
        for j in range(nb_columns):
            img = cv2.imread(db_path + resultats[j + k])
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            ax[i,j].imshow(img)
            ax[i,j].set_title(resultats[j + k])
        k = k + nb_columns

    plt.show()

# %% [markdown]
# ### Test_ 1: image requete tasse. Nous obtenons 7 bons resultats proche de notre image rquête

# %%
# image requete tasse
path_image_query = "./samples/tasse3.jpg"

resultats_noms, resultats_dist = RechercheImagesFromImageReq(path_image_query=path_image_query, indexed_db=indexed_db)

afficheResultats(image_query = path_image_query, resultats_noms = resultats_noms, resultats_dist = resultats_dist)
# Out:
# > recherche  --input  ./samples/tasse3.jpg
#
# Images                     Distances
# ------                     ---------
# obj89__285.png		 0.8701647763975464
#
# obj21__80.png		 0.9284969099589843
#
# obj89__310.png		 0.9365368624147019
#
# obj5__70.png		 0.9488076109744978
#
# obj89__315.png		 0.9496961885491617
#
# obj89__280.png		 0.950210494107727
#
# obj89__320.png		 0.9682329450747068
#
# obj5__75.png		 0.9921223045548107
#
# obj89__325.png		 0.9971380192975434
#
# obj89__275.png		 1.0008389010474221

# %%
# Visualiser les résulatas
AfficherResultats(resultats = resultats_noms)

# %% [markdown]
# ### Test 2 : tasse. 2 resultats proche en terme de forme et couleurs

# %%
# image requete tasse
path_image_query = "./samples/tasse.png"

resultats_noms, resultats_dist = RechercheImagesFromImageReq(path_image_query=path_image_query, indexed_db=indexed_db)

afficheResultats(image_query = path_image_query, resultats_noms = resultats_noms, resultats_dist = resultats_dist)
# Out:
# > recherche  --input  ./samples/tasse.png
#
# Images                     Distances
# ------                     ---------
# obj74__95.png		 1.2197666306538912
#
# obj65__330.png		 1.2323924566071263
#
# obj44__270.png		 1.3242207860032873
#
# obj97__255.png		 1.3364632178244644
#
# obj85__310.png		 1.384155836686201
#
# obj65__335.png		 1.3873811940886887
#
# obj97__250.png		 1.4111189829364776
#
# obj4__60.png		 1.415135687311908
#
# obj85__45.png		 1.416637555215681
#
# obj85__305.png		 1.4309094882861113

# %%
# Visualiser les résulatas
AfficherResultats(resultats = resultats_noms)

# %% [markdown]
# ### Test 3 : Hambourger. 3 bons résultats

# %%
# image requete tasse
path_image_query = "./samples/hambourger.jpeg"

resultats_noms, resultats_dist = RechercheImagesFromImageReq(path_image_query=path_image_query, indexed_db=indexed_db)

afficheResultats(image_query = path_image_query, resultats_noms = resultats_noms, resultats_dist = resultats_dist)
# Out:
# > recherche  --input  ./samples/hambourger.jpeg
#
# Images                     Distances
# ------                     ---------
# obj87__65.png		 1.554656336942679
#
# obj73__320.png		 1.5635363983667072
#
# obj73__325.png		 1.6525814713961617
#
# obj58__10.png		 1.7135529092778907
#
# obj73__330.png		 1.7527262497064964
#
# obj87__70.png		 1.7630237853355881
#
# obj31__170.png		 1.7893918720161315
#
# obj58__185.png		 1.8043811348959324
#
# obj54__255.png		 1.828632676239314
#
# obj31__160.png		 1.83128986661543

# %%
# Visualiser les résulatas
AfficherResultats(resultats = resultats_noms)

# %% [markdown]
# ### Test 4: automobile (camion).  3 bons résultats, 2 vehicule proche par la forme

# %%
# image requete tasse
path_image_query = "./samples/bus.jpeg"

resultats_noms, resultats_dist = RechercheImagesFromImageReq(path_image_query=path_image_query, indexed_db=indexed_db)

afficheResultats(image_query = path_image_query, resultats_noms = resultats_noms, resultats_dist = resultats_dist)
# Out:
# > recherche  --input  ./samples/bus.jpeg
#
# Images                     Distances
# ------                     ---------
# obj19__85.png		 1.5110779757498038
#
# obj19__275.png		 1.6184121629200252
#
# obj69__100.png		 1.6785954514784212
#
# obj19__270.png		 1.7094912428747477
#
# obj86__155.png		 1.7352818725806138
#
# obj86__150.png		 1.752078954206798
#
# obj86__145.png		 1.7528734909899208
#
# obj86__160.png		 1.7621142985632618
#
# obj69__105.png		 1.7723520633202496
#
# obj86__140.png		 1.77954170316599

# %%
# Visualiser les résulatas
AfficherResultats(resultats = resultats_noms)

# %% [markdown]
# ###  Test 5: canette coca. 8 bons résultats, 6 exactes par la couleur et la forme, et 2 par la forme. De même type.

# %%
# image requete tasse
path_image_query = "./samples/canettecoca.jpg"

resultats_noms, resultats_dist = RechercheImagesFromImageReq(path_image_query=path_image_query, indexed_db=indexed_db)

afficheResultats(image_query = path_image_query, resultats_noms = resultats_noms, resultats_dist = resultats_dist)
# Out:
# > recherche  --input  ./samples/canettecoca.jpg
#
# Images                     Distances
# ------                     ---------
# obj62__285.png		 1.4462015910993584
#
# obj62__290.png		 1.4522731064818393
#
# obj62__150.png		 1.5005627754189286
#
# obj15__115.png		 1.5224032032236101
#
# obj93__10.png		 1.522857262536252
#
# obj53__320.png		 1.5401404304251904
#
# obj93__5.png		 1.5430216208710958
#
# obj62__145.png		 1.5470309983374064
#
# obj7__30.png		 1.5500705997417916
#
# obj7__25.png		 1.5522232842928654

# %%
# Visualiser les résulatas
AfficherResultats(resultats = resultats_noms)

# %% [markdown]
# ###  Nous notons que les resultats peuvenr être améliorés, en trouvant encore un meilleur ajustement des poids, ou en proposant une autre métrique plus éfficace en exploitant les métriques couleur et forme.
